# %% [markdown]
# # Import Our Data

# %% [markdown]
# Load the data to your Google Drive. Then you can mount your drive and access the folder wherever you saved it.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Here, we are using the image_dataset_from_directory utilty, which reads images from a file path into a tf.Dataset object. This is much more memory efficient than reading images into lists! The dataset is already organized into training, test, and validation splits on my file system. The labels are inferred from the folder names.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "drive/My Drive/Teaching/Courses/BA 865/BA865-2022/Week 5/datasets/dogs-vs-cats"
  
train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 765 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 798 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
     print("data batch shape:", data_batch.shape)
     print("labels batch shape:", labels_batch.shape)
     break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# # Define Our Model

# %%
from tensorflow import keras 
from tensorflow.keras import layers
  
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         590080
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We have a binary outcome variable, hence our use of Sigmoid activation on the output layer. We will use binary cross-entropy loss as our loss function. And, we'll monitor accuracy.

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# This callback we are defining will write the current best model (and parameter values) to disk, based on minimum validation loss.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="drive/My Drive/Teaching/Courses/BA 865/BA865-2022/Week 5/convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %% [markdown]
# Note that batch size isn't defined here, because we defined it when we first created the tf.Dataset object! This Dataset object is an iterator, containing batches of images.

# %%
history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 73s 3s/step - loss: 0.7656 - accuracy: 0.5085 - val_loss: 0.6929 - val_accuracy: 0.5375
# Epoch 2/20
# 24/24 [==============================] - 3s 114ms/step - loss: 0.6987 - accuracy: 0.4993 - val_loss: 0.6908 - val_accuracy: 0.6475
# Epoch 3/20
# 24/24 [==============================] - 3s 100ms/step - loss: 0.7090 - accuracy: 0.5281 - val_loss: 0.6919 - val_accuracy: 0.5350
# Epoch 4/20
# 24/24 [==============================] - 3s 111ms/step - loss: 0.6973 - accuracy: 0.5503 - val_loss: 0.6854 - val_accuracy: 0.5700
# Epoch 5/20
# 24/24 [==============================] - 3s 104ms/step - loss: 0.6960 - accuracy: 0.5739 - val_loss: 0.6831 - val_accuracy: 0.5525
# Epoch 6/20
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6830 - accuracy: 0.5974 - val_loss: 0.6668 - val_accuracy: 0.5925
# Epoch 7/20
# 24/24 [==============================] - 3s 106ms/step - loss: 0.6651 - accuracy: 0.6039 - val_loss: 0.6411 - val_accuracy: 0.6650
# Epoch 8/20
# 24/24 [==============================] - 3s 103ms/step - loss: 0.6431 - accuracy: 0.6353 - val_loss: 0.6445 - val_accuracy: 0.6125
# Epoch 9/20
# 24/24 [==============================] - 3s 106ms/step - loss: 0.6072 - accuracy: 0.6732 - val_loss: 0.6211 - val_accuracy: 0.6750
# Epoch 10/20
# 24/24 [==============================] - 3s 106ms/step - loss: 0.5585 - accuracy: 0.7242 - val_loss: 0.6112 - val_accuracy: 0.6525
# Epoch 11/20
# 24/24 [==============================] - 3s 104ms/step - loss: 0.5343 - accuracy: 0.7542 - val_loss: 0.6342 - val_accuracy: 0.6650
# Epoch 12/20
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4703 - accuracy: 0.7660 - val_loss: 0.6942 - val_accuracy: 0.6300
# Epoch 13/20
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4865 - accuracy: 0.7582 - val_loss: 0.7202 - val_accuracy: 0.6425
# Epoch 14/20
# 24/24 [==============================] - 3s 103ms/step - loss: 0.3740 - accuracy: 0.8222 - val_loss: 0.7684 - val_accuracy: 0.6500
# Epoch 15/20
# 24/24 [==============================] - 3s 102ms/step - loss: 0.3578 - accuracy: 0.8392 - val_loss: 0.8218 - val_accuracy: 0.6150
# Epoch 16/20
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2869 - accuracy: 0.8824 - val_loss: 0.8189 - val_accuracy: 0.6375
# Epoch 17/20
# 24/24 [==============================] - 3s 102ms/step - loss: 0.2712 - accuracy: 0.8954 - val_loss: 1.0783 - val_accuracy: 0.6300
# Epoch 18/20
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2542 - accuracy: 0.9007 - val_loss: 0.8665 - val_accuracy: 0.6500
# Epoch 19/20
# 24/24 [==============================] - 3s 101ms/step - loss: 0.1068 - accuracy: 0.9660 - val_loss: 1.3732 - val_accuracy: 0.6250
# Epoch 20/20
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1488 - accuracy: 0.9386 - val_loss: 1.3862 - val_accuracy: 0.6350

# %% [markdown]
# And we can plot loss over training iterations...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# Note that we reach > 65% accuracy pretty quickly without much effort, but it plateaus there.

# %%
test_model = keras.models.load_model("drive/My Drive/Teaching/Courses/BA 865/BA865-2022/Week 5/convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 75s 2s/step - loss: 0.6738 - accuracy: 0.6203
# Test accuracy: 0.6203007698059082

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# To stave off the overfitting, we will first start by augmenting our dataset. This is a simple way to do it in a Sequential model, by adding a data augmentation layer. This step in our model will randomly mess with the data at each pass, flipping, rotating and zooming each image.

# %%
data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

# %% [markdown]
# You'll see that adding the aaumentation layer gets us another 5% bump in the validation accuracy of our model, up to about 72% fairly consistently. Note that we do a bit worse than the textbook claims, because we are using less data (I kept about 40% of the sample the book was working with).

# %%
from tensorflow import keras 
from tensorflow.keras import layers
  
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# We are making a different callback so we don't overwrite our last model (we might want to compare them)
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]

# And let's fit the model.
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 5s 111ms/step - loss: 0.9658 - accuracy: 0.5137 - val_loss: 0.6990 - val_accuracy: 0.5000
# Epoch 2/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.7003 - accuracy: 0.5255 - val_loss: 0.6885 - val_accuracy: 0.5100
# Epoch 3/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.7003 - accuracy: 0.5477 - val_loss: 0.6895 - val_accuracy: 0.5350
# Epoch 4/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.7310 - accuracy: 0.5503 - val_loss: 0.6817 - val_accuracy: 0.5575
# Epoch 5/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.6866 - accuracy: 0.5699 - val_loss: 0.6593 - val_accuracy: 0.6025
# Epoch 6/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6686 - accuracy: 0.5856 - val_loss: 0.7163 - val_accuracy: 0.5675
# Epoch 7/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.7243 - accuracy: 0.5778 - val_loss: 0.6523 - val_accuracy: 0.6525
# Epoch 8/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.7262 - accuracy: 0.6026 - val_loss: 0.6580 - val_accuracy: 0.6425
# Epoch 9/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6720 - accuracy: 0.6444 - val_loss: 0.6676 - val_accuracy: 0.5925
# Epoch 10/100
# 24/24 [==============================] - 3s 109ms/step - loss: 0.6568 - accuracy: 0.6196 - val_loss: 0.6311 - val_accuracy: 0.6325
# Epoch 11/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.6236 - accuracy: 0.6667 - val_loss: 0.6088 - val_accuracy: 0.6825
# Epoch 12/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.6201 - accuracy: 0.6758 - val_loss: 0.6845 - val_accuracy: 0.6125
# Epoch 13/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.6037 - accuracy: 0.6680 - val_loss: 0.6391 - val_accuracy: 0.6300
# Epoch 14/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.5880 - accuracy: 0.6706 - val_loss: 0.5738 - val_accuracy: 0.7050
# Epoch 15/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.6078 - accuracy: 0.6850 - val_loss: 0.5415 - val_accuracy: 0.7325
# Epoch 16/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.5706 - accuracy: 0.7020 - val_loss: 0.6033 - val_accuracy: 0.6500
# Epoch 17/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.5748 - accuracy: 0.7255 - val_loss: 0.5858 - val_accuracy: 0.6875
# Epoch 18/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.5444 - accuracy: 0.7216 - val_loss: 0.5554 - val_accuracy: 0.7325
# Epoch 19/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.5498 - accuracy: 0.7190 - val_loss: 0.5450 - val_accuracy: 0.7350
# Epoch 20/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.5317 - accuracy: 0.7569 - val_loss: 0.6260 - val_accuracy: 0.7150
# Epoch 21/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.4784 - accuracy: 0.7817 - val_loss: 0.5989 - val_accuracy: 0.7025
# Epoch 22/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.5515 - accuracy: 0.7307 - val_loss: 0.6167 - val_accuracy: 0.6900
# Epoch 23/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.5043 - accuracy: 0.7464 - val_loss: 0.6850 - val_accuracy: 0.6800
# Epoch 24/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.5120 - accuracy: 0.7673 - val_loss: 0.6389 - val_accuracy: 0.7225
# Epoch 25/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4661 - accuracy: 0.7621 - val_loss: 0.5975 - val_accuracy: 0.7125
# Epoch 26/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.4561 - accuracy: 0.7752 - val_loss: 0.6144 - val_accuracy: 0.7325
# Epoch 27/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.4755 - accuracy: 0.7752 - val_loss: 0.6560 - val_accuracy: 0.6775
# Epoch 28/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.4579 - accuracy: 0.7778 - val_loss: 0.6263 - val_accuracy: 0.7200
# Epoch 29/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.4680 - accuracy: 0.7739 - val_loss: 0.5529 - val_accuracy: 0.7450
# Epoch 30/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4442 - accuracy: 0.7895 - val_loss: 0.6423 - val_accuracy: 0.7050
# Epoch 31/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.4194 - accuracy: 0.8105 - val_loss: 0.6320 - val_accuracy: 0.7200
# Epoch 32/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.4122 - accuracy: 0.8235 - val_loss: 0.5213 - val_accuracy: 0.7450
# Epoch 33/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.3983 - accuracy: 0.8288 - val_loss: 0.7724 - val_accuracy: 0.6850
# Epoch 34/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.3946 - accuracy: 0.8275 - val_loss: 0.6551 - val_accuracy: 0.7375
# Epoch 35/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4076 - accuracy: 0.8157 - val_loss: 0.6040 - val_accuracy: 0.7325
# Epoch 36/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.3913 - accuracy: 0.8157 - val_loss: 0.6718 - val_accuracy: 0.7350
# Epoch 37/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.3668 - accuracy: 0.8405 - val_loss: 0.6274 - val_accuracy: 0.7425
# Epoch 38/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.3915 - accuracy: 0.8222 - val_loss: 0.7977 - val_accuracy: 0.7300
# Epoch 39/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.3591 - accuracy: 0.8261 - val_loss: 1.2605 - val_accuracy: 0.6700
# Epoch 40/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.3620 - accuracy: 0.8366 - val_loss: 0.5444 - val_accuracy: 0.7700
# Epoch 41/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.3662 - accuracy: 0.8431 - val_loss: 0.5796 - val_accuracy: 0.7700
# Epoch 42/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.3757 - accuracy: 0.8405 - val_loss: 0.6999 - val_accuracy: 0.7350
# Epoch 43/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.3672 - accuracy: 0.8405 - val_loss: 0.6771 - val_accuracy: 0.7525
# Epoch 44/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.3875 - accuracy: 0.8275 - val_loss: 1.0084 - val_accuracy: 0.7200
# Epoch 45/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.3506 - accuracy: 0.8340 - val_loss: 0.6204 - val_accuracy: 0.7400
# Epoch 46/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.3230 - accuracy: 0.8641 - val_loss: 0.7158 - val_accuracy: 0.7525
# Epoch 47/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.3187 - accuracy: 0.8575 - val_loss: 0.6055 - val_accuracy: 0.7725
# Epoch 48/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.3112 - accuracy: 0.8627 - val_loss: 0.7482 - val_accuracy: 0.7625
# Epoch 49/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2797 - accuracy: 0.8758 - val_loss: 0.8118 - val_accuracy: 0.7500
# Epoch 50/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.3035 - accuracy: 0.8627 - val_loss: 0.7306 - val_accuracy: 0.7425
# Epoch 51/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.2736 - accuracy: 0.8784 - val_loss: 0.7656 - val_accuracy: 0.7625
# Epoch 52/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.3078 - accuracy: 0.8732 - val_loss: 0.6348 - val_accuracy: 0.7825
# Epoch 53/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.2714 - accuracy: 0.8889 - val_loss: 0.6799 - val_accuracy: 0.7550
# Epoch 54/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2912 - accuracy: 0.8706 - val_loss: 0.8159 - val_accuracy: 0.7475
# Epoch 55/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2438 - accuracy: 0.8954 - val_loss: 0.9652 - val_accuracy: 0.7525
# Epoch 56/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2296 - accuracy: 0.9137 - val_loss: 0.8368 - val_accuracy: 0.7500
# Epoch 57/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2606 - accuracy: 0.8941 - val_loss: 0.8865 - val_accuracy: 0.7725
# Epoch 58/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.2540 - accuracy: 0.8915 - val_loss: 0.8021 - val_accuracy: 0.7475
# Epoch 59/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2461 - accuracy: 0.9007 - val_loss: 0.8270 - val_accuracy: 0.7450
# Epoch 60/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.2681 - accuracy: 0.8863 - val_loss: 0.7914 - val_accuracy: 0.7575
# Epoch 61/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2481 - accuracy: 0.9046 - val_loss: 0.9208 - val_accuracy: 0.7300
# Epoch 62/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.2006 - accuracy: 0.9111 - val_loss: 0.8198 - val_accuracy: 0.7425
# Epoch 63/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.2014 - accuracy: 0.9124 - val_loss: 0.9267 - val_accuracy: 0.7650
# Epoch 64/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.2178 - accuracy: 0.9124 - val_loss: 0.8284 - val_accuracy: 0.7725
# Epoch 65/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.2105 - accuracy: 0.9137 - val_loss: 0.9381 - val_accuracy: 0.7450
# Epoch 66/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2110 - accuracy: 0.9150 - val_loss: 0.7711 - val_accuracy: 0.7500
# Epoch 67/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1969 - accuracy: 0.9229 - val_loss: 0.9973 - val_accuracy: 0.7550
# Epoch 68/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2258 - accuracy: 0.9059 - val_loss: 0.8657 - val_accuracy: 0.7375
# Epoch 69/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2404 - accuracy: 0.9137 - val_loss: 0.8781 - val_accuracy: 0.7350
# Epoch 70/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1808 - accuracy: 0.9359 - val_loss: 0.9915 - val_accuracy: 0.7725
# Epoch 71/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1671 - accuracy: 0.9386 - val_loss: 1.1399 - val_accuracy: 0.7550
# Epoch 72/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1945 - accuracy: 0.9359 - val_loss: 1.0585 - val_accuracy: 0.7475
# Epoch 73/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1846 - accuracy: 0.9281 - val_loss: 0.8545 - val_accuracy: 0.7550
# Epoch 74/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2002 - accuracy: 0.9150 - val_loss: 1.1473 - val_accuracy: 0.7725
# Epoch 75/100
# 24/24 [==============================] - 3s 109ms/step - loss: 0.1441 - accuracy: 0.9359 - val_loss: 0.9978 - val_accuracy: 0.7750
# Epoch 76/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1585 - accuracy: 0.9438 - val_loss: 1.0493 - val_accuracy: 0.7725
# Epoch 77/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2455 - accuracy: 0.9216 - val_loss: 1.2006 - val_accuracy: 0.6975
# Epoch 78/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1375 - accuracy: 0.9542 - val_loss: 1.2103 - val_accuracy: 0.7425
# Epoch 79/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2096 - accuracy: 0.9281 - val_loss: 0.9591 - val_accuracy: 0.7675
# Epoch 80/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1061 - accuracy: 0.9608 - val_loss: 1.0849 - val_accuracy: 0.7700
# Epoch 81/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1580 - accuracy: 0.9425 - val_loss: 1.3512 - val_accuracy: 0.7300
# Epoch 82/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1743 - accuracy: 0.9359 - val_loss: 1.0089 - val_accuracy: 0.7525
# Epoch 83/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1236 - accuracy: 0.9673 - val_loss: 0.9762 - val_accuracy: 0.7450
# Epoch 84/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1468 - accuracy: 0.9451 - val_loss: 1.2685 - val_accuracy: 0.7300
# Epoch 85/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1289 - accuracy: 0.9516 - val_loss: 1.0140 - val_accuracy: 0.7825
# Epoch 86/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.1173 - accuracy: 0.9660 - val_loss: 0.9894 - val_accuracy: 0.7725
# Epoch 87/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1501 - accuracy: 0.9425 - val_loss: 1.2874 - val_accuracy: 0.7400
# Epoch 88/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1101 - accuracy: 0.9569 - val_loss: 1.3873 - val_accuracy: 0.7550
# Epoch 89/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1872 - accuracy: 0.9386 - val_loss: 1.1550 - val_accuracy: 0.7350
# Epoch 90/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1014 - accuracy: 0.9686 - val_loss: 1.6711 - val_accuracy: 0.7075
# Epoch 91/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1879 - accuracy: 0.9333 - val_loss: 1.2056 - val_accuracy: 0.7725
# Epoch 92/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0989 - accuracy: 0.9647 - val_loss: 1.3177 - val_accuracy: 0.7850
# Epoch 93/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.1653 - accuracy: 0.9438 - val_loss: 0.9835 - val_accuracy: 0.7450
# Epoch 94/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.1354 - accuracy: 0.9529 - val_loss: 1.5015 - val_accuracy: 0.7325
# Epoch 95/100
# 24/24 [==============================] - 3s 109ms/step - loss: 0.1210 - accuracy: 0.9634 - val_loss: 1.3485 - val_accuracy: 0.7200
# Epoch 96/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0925 - accuracy: 0.9608 - val_loss: 1.3808 - val_accuracy: 0.7150
# Epoch 97/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.1341 - accuracy: 0.9503 - val_loss: 1.4016 - val_accuracy: 0.7375
# Epoch 98/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1070 - accuracy: 0.9660 - val_loss: 1.4726 - val_accuracy: 0.7550
# Epoch 99/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1313 - accuracy: 0.9582 - val_loss: 1.4050 - val_accuracy: 0.7325
# Epoch 100/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1164 - accuracy: 0.9660 - val_loss: 1.3122 - val_accuracy: 0.7550

# %% [markdown]
# Let's plot the accuracy over training again...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And let's check the test accuracy.

# %%
test_model = keras.models.load_model("convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset) 
print(f"Test accuracy: {test_acc}")

# %% [markdown]
# # Feature Extraction from a Pre-Trained Model: VGG16

# %% [markdown]
# Now we are going to load a pre-trained model, to leverage its convolutional base for our task. Note that the convolutional base, alone, is about 15 million parameters.

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False, # Throw away the densely connected layer at the end.
    input_shape=(180, 180, 3)) # Optional - just for model.summary() call.

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we run our training, validation, and test data images through the convolutional base, get the feature representations of each according to VGG, and then store them alongside their cat/dog labels.

# %%
import numpy as np
  
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)
  
train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)

# %% [markdown]
# Here, you can see the dimensionality of the features associated with a single image. The VGG output from the convolutional layer comprises of 512 feature-specific feature maps, that are each 5x5 in dimensionality.

# %%
print(train_features[0].shape)
# Out:
# (5, 5, 512)

# %% [markdown]
# So, now we are going to define a new model that sits on the end of the VGG convolutional layer. It'll take those 512 featuremaps, flatten them, pass them to a Dense layer of 256 nodes, and then feed to a one-node sigmoid output (with some Dropout). This model will fit extremely quickly, and it's accuracy will be way higher, approaching 97%

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
  
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 1s 13ms/step - loss: 31.9086 - accuracy: 0.8993 - val_loss: 14.9422 - val_accuracy: 0.9175
# Epoch 2/20
# 24/24 [==============================] - 0s 10ms/step - loss: 2.6353 - accuracy: 0.9752 - val_loss: 6.0931 - val_accuracy: 0.9500
# Epoch 3/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.8183 - accuracy: 0.9948 - val_loss: 9.2609 - val_accuracy: 0.9275
# Epoch 4/20
# 24/24 [==============================] - 0s 7ms/step - loss: 4.5199 - accuracy: 0.9725 - val_loss: 8.2621 - val_accuracy: 0.9375
# Epoch 5/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4943 - accuracy: 0.9948 - val_loss: 8.1591 - val_accuracy: 0.9550
# Epoch 6/20
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2443 - accuracy: 0.9961 - val_loss: 12.1872 - val_accuracy: 0.9475
# Epoch 7/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1657 - accuracy: 0.9948 - val_loss: 7.9589 - val_accuracy: 0.9600
# Epoch 8/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.6147 - accuracy: 0.9961 - val_loss: 5.4036 - val_accuracy: 0.9525
# Epoch 9/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1477 - accuracy: 0.9974 - val_loss: 6.6605 - val_accuracy: 0.9475
# Epoch 10/20
# 24/24 [==============================] - 0s 8ms/step - loss: 0.8388 - accuracy: 0.9922 - val_loss: 6.6964 - val_accuracy: 0.9600
# Epoch 11/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2894 - accuracy: 0.9961 - val_loss: 18.6164 - val_accuracy: 0.9375
# Epoch 12/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4440 - accuracy: 0.9948 - val_loss: 16.7651 - val_accuracy: 0.9375
# Epoch 13/20
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1031 - accuracy: 0.9974 - val_loss: 11.2063 - val_accuracy: 0.9525
# Epoch 14/20
# 24/24 [==============================] - 0s 7ms/step - loss: 4.6669e-17 - accuracy: 1.0000 - val_loss: 11.2063 - val_accuracy: 0.9525
# Epoch 15/20
# 24/24 [==============================] - 0s 7ms/step - loss: 2.0035e-16 - accuracy: 1.0000 - val_loss: 11.2063 - val_accuracy: 0.9525
# Epoch 16/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.9432 - accuracy: 0.9922 - val_loss: 7.4665 - val_accuracy: 0.9525
# Epoch 17/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2415 - accuracy: 0.9974 - val_loss: 8.0460 - val_accuracy: 0.9550
# Epoch 18/20
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.0460 - val_accuracy: 0.9550
# Epoch 19/20
# 24/24 [==============================] - 0s 8ms/step - loss: 1.9285e-27 - accuracy: 1.0000 - val_loss: 8.0460 - val_accuracy: 0.9550
# Epoch 20/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1407 - accuracy: 0.9987 - val_loss: 23.7370 - val_accuracy: 0.9350

# %% [markdown]
# Plotting performance here...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And, evaluating performance on the test data.

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features,test_labels) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 0s 3ms/step - loss: 7.4644 - accuracy: 0.9574
# Test accuracy: 0.9573934674263

# %% [markdown]
# # Fine-Tuning from a Pre-Trained Model (with Data-Augmentation)

# %% [markdown]
# Here we are going to load the convolutional base, and actually use it inside our network (though we will freeze its parameters so we don't try to update them as we go, since that would ruin the model and add lots of computation time).

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False # The convolutional layers won't be updatable; we just build on them using Functional API.

data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])
  
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  tf.__operators__.getitem (S  (None, 180, 180, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 180, 180, 3)      0
#
#  vgg16 (Functional)          (None, None, None, 512)   14714688
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_4 (Dense)             (None, 256)               3277056
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 17,992,001
# Trainable params: 3,277,313
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# And now we can fit our model. This is slower because our forward pass has to go through the VGG convolutional base each iteration (rather than the one time we did when we used it for feature extraction.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset, # Note we are back to working with our original training dataset.
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 5s 152ms/step - loss: 26.2179 - accuracy: 0.8680 - val_loss: 4.9792 - val_accuracy: 0.9525
# Epoch 2/50
# 24/24 [==============================] - 4s 152ms/step - loss: 8.7457 - accuracy: 0.9307 - val_loss: 3.8188 - val_accuracy: 0.9600
# Epoch 3/50
# 24/24 [==============================] - 4s 138ms/step - loss: 4.5577 - accuracy: 0.9582 - val_loss: 7.1023 - val_accuracy: 0.9475
# Epoch 4/50
# 24/24 [==============================] - 4s 137ms/step - loss: 4.6958 - accuracy: 0.9569 - val_loss: 6.8383 - val_accuracy: 0.9425
# Epoch 5/50
# 24/24 [==============================] - 4s 140ms/step - loss: 4.3970 - accuracy: 0.9647 - val_loss: 8.7187 - val_accuracy: 0.9425
# Epoch 6/50
# 24/24 [==============================] - 4s 138ms/step - loss: 4.2388 - accuracy: 0.9595 - val_loss: 9.1188 - val_accuracy: 0.9525
# Epoch 7/50
# 24/24 [==============================] - 4s 142ms/step - loss: 2.5272 - accuracy: 0.9752 - val_loss: 12.3043 - val_accuracy: 0.9500
# Epoch 8/50
# 24/24 [==============================] - 4s 139ms/step - loss: 3.3198 - accuracy: 0.9699 - val_loss: 10.6709 - val_accuracy: 0.9325
# Epoch 9/50
# 24/24 [==============================] - 4s 139ms/step - loss: 4.1287 - accuracy: 0.9686 - val_loss: 15.9855 - val_accuracy: 0.9500
# Epoch 10/50
# 24/24 [==============================] - 4s 140ms/step - loss: 2.8200 - accuracy: 0.9752 - val_loss: 8.1346 - val_accuracy: 0.9475
# Epoch 11/50
# 24/24 [==============================] - 4s 140ms/step - loss: 2.8488 - accuracy: 0.9778 - val_loss: 10.1749 - val_accuracy: 0.9450
# Epoch 12/50
# 24/24 [==============================] - 4s 139ms/step - loss: 2.0171 - accuracy: 0.9765 - val_loss: 13.6410 - val_accuracy: 0.9475
# Epoch 13/50
# 24/24 [==============================] - 4s 137ms/step - loss: 2.0805 - accuracy: 0.9843 - val_loss: 15.7161 - val_accuracy: 0.9450
# Epoch 14/50
# 24/24 [==============================] - 4s 140ms/step - loss: 2.0524 - accuracy: 0.9778 - val_loss: 14.5743 - val_accuracy: 0.9475
# Epoch 15/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.8026 - accuracy: 0.9817 - val_loss: 9.4080 - val_accuracy: 0.9600
# Epoch 16/50
# 24/24 [==============================] - 4s 142ms/step - loss: 1.6963 - accuracy: 0.9817 - val_loss: 12.5194 - val_accuracy: 0.9450
# Epoch 17/50
# 24/24 [==============================] - 4s 141ms/step - loss: 0.5048 - accuracy: 0.9922 - val_loss: 15.0913 - val_accuracy: 0.9450
# Epoch 18/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.6684 - accuracy: 0.9895 - val_loss: 16.0389 - val_accuracy: 0.9500
# Epoch 19/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.8503 - accuracy: 0.9804 - val_loss: 13.8064 - val_accuracy: 0.9500
# Epoch 20/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.6153 - accuracy: 0.9869 - val_loss: 15.7618 - val_accuracy: 0.9500
# Epoch 21/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.5205 - accuracy: 0.9922 - val_loss: 13.4738 - val_accuracy: 0.9500
# Epoch 22/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.8195 - accuracy: 0.9869 - val_loss: 16.2688 - val_accuracy: 0.9475
# Epoch 23/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.5253 - accuracy: 0.9922 - val_loss: 17.9083 - val_accuracy: 0.9450
# Epoch 24/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.7023 - accuracy: 0.9895 - val_loss: 16.8871 - val_accuracy: 0.9475
# Epoch 25/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.3239 - accuracy: 0.9948 - val_loss: 21.6795 - val_accuracy: 0.9450
# Epoch 26/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.5713 - accuracy: 0.9869 - val_loss: 15.7296 - val_accuracy: 0.9550
# Epoch 27/50
# 24/24 [==============================] - 4s 140ms/step - loss: 1.2408 - accuracy: 0.9922 - val_loss: 14.3244 - val_accuracy: 0.9500
# Epoch 28/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.5976 - accuracy: 0.9869 - val_loss: 28.7253 - val_accuracy: 0.9425
# Epoch 29/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.9976 - accuracy: 0.9908 - val_loss: 14.0854 - val_accuracy: 0.9400
# Epoch 30/50
# 24/24 [==============================] - 4s 140ms/step - loss: 1.8491 - accuracy: 0.9869 - val_loss: 16.4107 - val_accuracy: 0.9525
# Epoch 31/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.0548 - accuracy: 0.9869 - val_loss: 11.9382 - val_accuracy: 0.9525
# Epoch 32/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.1035 - accuracy: 0.9882 - val_loss: 10.1816 - val_accuracy: 0.9500
# Epoch 33/50
# 24/24 [==============================] - 4s 139ms/step - loss: 2.2973 - accuracy: 0.9752 - val_loss: 10.5167 - val_accuracy: 0.9500
# Epoch 34/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.1693 - accuracy: 0.9895 - val_loss: 15.7934 - val_accuracy: 0.9550
# Epoch 35/50
# 24/24 [==============================] - 4s 138ms/step - loss: 1.3555 - accuracy: 0.9922 - val_loss: 13.6497 - val_accuracy: 0.9400
# Epoch 36/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.5766 - accuracy: 0.9908 - val_loss: 11.5039 - val_accuracy: 0.9450
# Epoch 37/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.4363 - accuracy: 0.9948 - val_loss: 10.9750 - val_accuracy: 0.9500
# Epoch 38/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.5592 - accuracy: 0.9961 - val_loss: 17.3332 - val_accuracy: 0.9550
# Epoch 39/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.0371 - accuracy: 0.9987 - val_loss: 10.6717 - val_accuracy: 0.9550
# Epoch 40/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.9349 - accuracy: 0.9856 - val_loss: 10.2219 - val_accuracy: 0.9475
# Epoch 41/50
# 24/24 [==============================] - 4s 140ms/step - loss: 0.2462 - accuracy: 0.9974 - val_loss: 10.8550 - val_accuracy: 0.9475
# Epoch 42/50
# 24/24 [==============================] - 4s 139ms/step - loss: 1.0208 - accuracy: 0.9922 - val_loss: 11.0028 - val_accuracy: 0.9500
# Epoch 43/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.3931 - accuracy: 0.9935 - val_loss: 13.3594 - val_accuracy: 0.9550
# Epoch 44/50
# 24/24 [==============================] - 4s 137ms/step - loss: 1.0009 - accuracy: 0.9922 - val_loss: 12.9342 - val_accuracy: 0.9575
# Epoch 45/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.1937 - accuracy: 0.9974 - val_loss: 13.9216 - val_accuracy: 0.9500
# Epoch 46/50
# 24/24 [==============================] - 4s 139ms/step - loss: 0.6439 - accuracy: 0.9908 - val_loss: 14.7264 - val_accuracy: 0.9275
# Epoch 47/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.9293 - accuracy: 0.9908 - val_loss: 11.5633 - val_accuracy: 0.9500
# Epoch 48/50
# 24/24 [==============================] - 4s 137ms/step - loss: 0.0761 - accuracy: 0.9935 - val_loss: 11.3786 - val_accuracy: 0.9600
# Epoch 49/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.3250 - accuracy: 0.9948 - val_loss: 10.9048 - val_accuracy: 0.9600
# Epoch 50/50
# 24/24 [==============================] - 4s 138ms/step - loss: 0.2567 - accuracy: 0.9961 - val_loss: 10.4500 - val_accuracy: 0.9550
