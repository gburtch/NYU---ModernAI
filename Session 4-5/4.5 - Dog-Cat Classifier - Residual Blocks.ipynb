# %% [markdown]
# # Import Our Data

# %% [markdown]
# Save the data to your Google Drive. Then you can mount your drive and access the folder from wherever you saved it.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Here, we are using the image_dataset_from_directory utilty, which reads images from a file path into a tf.Dataset object. This is much more memory efficient than reading images into lists! The dataset is already organized into training, test, and validation splits on my file system. The labels are inferred from the folder names.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "drive/My Drive/Teaching/Courses/BA 865/BA865-2022/Week 5/datasets/dogs-vs-cats"
  
train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 765 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 798 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
     print("data batch shape:", data_batch.shape)
     print("labels batch shape:", labels_batch.shape)
     break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# # Define Our Model

# %%
from tensorflow import keras 
from tensorflow.keras import layers

data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)
 
for size in [32, 64, 128]:
    residual = x
 
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(size, 3, padding="same", use_bias=False)(x)
  
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(size, 3, padding="same", use_bias=False)(x)
  
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
  
    residual = layers.Conv2D(size, 1, strides=2, padding="same", use_bias=False)(residual)
    x = layers.add([x, residual])
  
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# We have a binary outcome variable, hence our use of Sigmoid activation on the output layer. We will use binary cross-entropy loss as our loss function. And, we'll monitor accuracy.

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# This callback we are defining will write the current best model (and parameter values) to disk, based on minimum validation loss.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="Xception.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %% [markdown]
# Note that batch size isn't defined here, because we defined it when we first created the tf.Dataset object! This Dataset object is an iterator, containing batches of images.

# %%
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 127s 4s/step - loss: 1.6773 - accuracy: 0.5307 - val_loss: 0.8062 - val_accuracy: 0.5000
# Epoch 2/100
# 24/24 [==============================] - 4s 158ms/step - loss: 1.0568 - accuracy: 0.5307 - val_loss: 0.7063 - val_accuracy: 0.5000
# Epoch 3/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.8855 - accuracy: 0.5451 - val_loss: 0.7258 - val_accuracy: 0.5000
# Epoch 4/100
# 24/24 [==============================] - 4s 151ms/step - loss: 0.8398 - accuracy: 0.5451 - val_loss: 0.7588 - val_accuracy: 0.5000
# Epoch 5/100
# 24/24 [==============================] - 4s 151ms/step - loss: 0.8343 - accuracy: 0.5595 - val_loss: 0.7210 - val_accuracy: 0.5000
# Epoch 6/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.7602 - accuracy: 0.5477 - val_loss: 0.6963 - val_accuracy: 0.5050
# Epoch 7/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.7746 - accuracy: 0.5503 - val_loss: 0.7371 - val_accuracy: 0.5000
# Epoch 8/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.7261 - accuracy: 0.5725 - val_loss: 0.7647 - val_accuracy: 0.5000
# Epoch 9/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.6999 - accuracy: 0.5765 - val_loss: 0.7821 - val_accuracy: 0.5000
# Epoch 10/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.7068 - accuracy: 0.6118 - val_loss: 0.7133 - val_accuracy: 0.4575
# Epoch 11/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.6614 - accuracy: 0.6052 - val_loss: 0.7634 - val_accuracy: 0.5075
# Epoch 12/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.6528 - accuracy: 0.6379 - val_loss: 1.0490 - val_accuracy: 0.5000
# Epoch 13/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.6277 - accuracy: 0.6497 - val_loss: 0.8145 - val_accuracy: 0.5325
# Epoch 14/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.6251 - accuracy: 0.6667 - val_loss: 0.7551 - val_accuracy: 0.5475
# Epoch 15/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.6075 - accuracy: 0.6967 - val_loss: 0.8282 - val_accuracy: 0.5075
# Epoch 16/100
# 24/24 [==============================] - 4s 152ms/step - loss: 0.5947 - accuracy: 0.6915 - val_loss: 0.8370 - val_accuracy: 0.5550
# Epoch 17/100
# 24/24 [==============================] - 4s 158ms/step - loss: 0.6095 - accuracy: 0.6824 - val_loss: 0.6581 - val_accuracy: 0.6175
# Epoch 18/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5784 - accuracy: 0.7020 - val_loss: 0.8187 - val_accuracy: 0.5550
# Epoch 19/100
# 24/24 [==============================] - 4s 150ms/step - loss: 0.5668 - accuracy: 0.7255 - val_loss: 1.1824 - val_accuracy: 0.5400
# Epoch 20/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.5551 - accuracy: 0.7059 - val_loss: 0.6740 - val_accuracy: 0.6225
# Epoch 21/100
# 24/24 [==============================] - 4s 158ms/step - loss: 0.5544 - accuracy: 0.7124 - val_loss: 0.6455 - val_accuracy: 0.6550
# Epoch 22/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5437 - accuracy: 0.7176 - val_loss: 0.9737 - val_accuracy: 0.5700
# Epoch 23/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.5249 - accuracy: 0.7477 - val_loss: 0.7204 - val_accuracy: 0.6525
# Epoch 24/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.5165 - accuracy: 0.7542 - val_loss: 0.8160 - val_accuracy: 0.6400
# Epoch 25/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.4938 - accuracy: 0.7608 - val_loss: 0.7161 - val_accuracy: 0.6300
# Epoch 26/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4802 - accuracy: 0.7699 - val_loss: 0.6924 - val_accuracy: 0.6300
# Epoch 27/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4823 - accuracy: 0.7673 - val_loss: 0.6616 - val_accuracy: 0.6575
# Epoch 28/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4887 - accuracy: 0.7608 - val_loss: 0.7294 - val_accuracy: 0.6950
# Epoch 29/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.4515 - accuracy: 0.7869 - val_loss: 0.6772 - val_accuracy: 0.7100
# Epoch 30/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4500 - accuracy: 0.7974 - val_loss: 0.7501 - val_accuracy: 0.6300
# Epoch 31/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4585 - accuracy: 0.8026 - val_loss: 0.7350 - val_accuracy: 0.6600
# Epoch 32/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.4229 - accuracy: 0.8105 - val_loss: 0.7404 - val_accuracy: 0.6850
# Epoch 33/100
# 24/24 [==============================] - 4s 152ms/step - loss: 0.4085 - accuracy: 0.8144 - val_loss: 0.8677 - val_accuracy: 0.6725
# Epoch 34/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.4042 - accuracy: 0.8183 - val_loss: 0.7922 - val_accuracy: 0.6175
# Epoch 35/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.4097 - accuracy: 0.8288 - val_loss: 0.9806 - val_accuracy: 0.6400
# Epoch 36/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.4159 - accuracy: 0.8183 - val_loss: 0.6696 - val_accuracy: 0.6925
# Epoch 37/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.3667 - accuracy: 0.8314 - val_loss: 0.7193 - val_accuracy: 0.6975
# Epoch 38/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.3409 - accuracy: 0.8588 - val_loss: 0.8711 - val_accuracy: 0.6775
# Epoch 39/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.3529 - accuracy: 0.8392 - val_loss: 1.0575 - val_accuracy: 0.6650
# Epoch 40/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.3739 - accuracy: 0.8196 - val_loss: 1.7340 - val_accuracy: 0.5625
# Epoch 41/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.3484 - accuracy: 0.8562 - val_loss: 0.9712 - val_accuracy: 0.6225
# Epoch 42/100
# 24/24 [==============================] - 4s 152ms/step - loss: 0.2892 - accuracy: 0.8641 - val_loss: 0.7132 - val_accuracy: 0.7150
# Epoch 43/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.3377 - accuracy: 0.8405 - val_loss: 0.7330 - val_accuracy: 0.7000
# Epoch 44/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.2924 - accuracy: 0.8797 - val_loss: 1.6287 - val_accuracy: 0.5875
# Epoch 45/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.3512 - accuracy: 0.8523 - val_loss: 0.7928 - val_accuracy: 0.7425
# Epoch 46/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.2966 - accuracy: 0.8680 - val_loss: 1.0276 - val_accuracy: 0.6925
# Epoch 47/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.2966 - accuracy: 0.8719 - val_loss: 0.8955 - val_accuracy: 0.6875
# Epoch 48/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.3014 - accuracy: 0.8876 - val_loss: 0.7036 - val_accuracy: 0.7125
# Epoch 49/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.2835 - accuracy: 0.8876 - val_loss: 0.8903 - val_accuracy: 0.7025
# Epoch 50/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.2499 - accuracy: 0.8980 - val_loss: 1.5083 - val_accuracy: 0.6325
# Epoch 51/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.2656 - accuracy: 0.8876 - val_loss: 0.7026 - val_accuracy: 0.7500
# Epoch 52/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.2464 - accuracy: 0.8967 - val_loss: 1.1024 - val_accuracy: 0.6825
# Epoch 53/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.2394 - accuracy: 0.9124 - val_loss: 0.7011 - val_accuracy: 0.7575
# Epoch 54/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.2239 - accuracy: 0.8993 - val_loss: 2.2743 - val_accuracy: 0.6175
# Epoch 55/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1751 - accuracy: 0.9307 - val_loss: 1.9324 - val_accuracy: 0.5900
# Epoch 56/100
# 24/24 [==============================] - 4s 158ms/step - loss: 0.2305 - accuracy: 0.9163 - val_loss: 1.0063 - val_accuracy: 0.7275
# Epoch 57/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.1807 - accuracy: 0.9425 - val_loss: 0.9482 - val_accuracy: 0.6950
# Epoch 58/100
# 24/24 [==============================] - 4s 158ms/step - loss: 0.1964 - accuracy: 0.9137 - val_loss: 1.5974 - val_accuracy: 0.7225
# Epoch 59/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.2189 - accuracy: 0.9190 - val_loss: 1.3871 - val_accuracy: 0.6750
# Epoch 60/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.1249 - accuracy: 0.9529 - val_loss: 1.4801 - val_accuracy: 0.6450
# Epoch 61/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.2222 - accuracy: 0.9098 - val_loss: 3.2350 - val_accuracy: 0.5525
# Epoch 62/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.1669 - accuracy: 0.9242 - val_loss: 1.7779 - val_accuracy: 0.6625
# Epoch 63/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1829 - accuracy: 0.9359 - val_loss: 1.0285 - val_accuracy: 0.7175
# Epoch 64/100
# 24/24 [==============================] - 4s 152ms/step - loss: 0.1388 - accuracy: 0.9373 - val_loss: 3.2079 - val_accuracy: 0.5750
# Epoch 65/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.1268 - accuracy: 0.9542 - val_loss: 1.3651 - val_accuracy: 0.7150
# Epoch 66/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.1501 - accuracy: 0.9529 - val_loss: 1.0925 - val_accuracy: 0.7325
# Epoch 67/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1573 - accuracy: 0.9477 - val_loss: 2.4136 - val_accuracy: 0.6300
# Epoch 68/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.1113 - accuracy: 0.9542 - val_loss: 3.0305 - val_accuracy: 0.6350
# Epoch 69/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1445 - accuracy: 0.9425 - val_loss: 0.9306 - val_accuracy: 0.7525
# Epoch 70/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.1538 - accuracy: 0.9412 - val_loss: 2.0732 - val_accuracy: 0.6775
# Epoch 71/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.0785 - accuracy: 0.9752 - val_loss: 1.4169 - val_accuracy: 0.6700
# Epoch 72/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1802 - accuracy: 0.9307 - val_loss: 1.4290 - val_accuracy: 0.6850
# Epoch 73/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1604 - accuracy: 0.9464 - val_loss: 2.1075 - val_accuracy: 0.6475
# Epoch 74/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.1157 - accuracy: 0.9634 - val_loss: 2.0494 - val_accuracy: 0.6300
# Epoch 75/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.1304 - accuracy: 0.9595 - val_loss: 2.3885 - val_accuracy: 0.6050
# Epoch 76/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0883 - accuracy: 0.9752 - val_loss: 1.5211 - val_accuracy: 0.6975
# Epoch 77/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.0995 - accuracy: 0.9621 - val_loss: 1.6683 - val_accuracy: 0.6900
# Epoch 78/100
# 24/24 [==============================] - 4s 152ms/step - loss: 0.1066 - accuracy: 0.9647 - val_loss: 1.5058 - val_accuracy: 0.7300
# Epoch 79/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0712 - accuracy: 0.9712 - val_loss: 1.6718 - val_accuracy: 0.7225
# Epoch 80/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.1531 - accuracy: 0.9464 - val_loss: 1.5545 - val_accuracy: 0.6950
# Epoch 81/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0677 - accuracy: 0.9699 - val_loss: 7.2478 - val_accuracy: 0.5150
# Epoch 82/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1008 - accuracy: 0.9634 - val_loss: 1.9589 - val_accuracy: 0.6650
# Epoch 83/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.1014 - accuracy: 0.9595 - val_loss: 4.5387 - val_accuracy: 0.5700
# Epoch 84/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.0835 - accuracy: 0.9817 - val_loss: 2.1751 - val_accuracy: 0.6850
# Epoch 85/100
# 24/24 [==============================] - 4s 157ms/step - loss: 0.0460 - accuracy: 0.9817 - val_loss: 1.2216 - val_accuracy: 0.7475
# Epoch 86/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.1384 - accuracy: 0.9569 - val_loss: 1.6801 - val_accuracy: 0.7300
# Epoch 87/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.1002 - accuracy: 0.9699 - val_loss: 2.1466 - val_accuracy: 0.7400
# Epoch 88/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0661 - accuracy: 0.9725 - val_loss: 1.4548 - val_accuracy: 0.7450
# Epoch 89/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.0609 - accuracy: 0.9778 - val_loss: 6.0341 - val_accuracy: 0.5775
# Epoch 90/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.1869 - accuracy: 0.9412 - val_loss: 1.5184 - val_accuracy: 0.7400
# Epoch 91/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.1094 - accuracy: 0.9686 - val_loss: 2.3608 - val_accuracy: 0.6825
# Epoch 92/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0503 - accuracy: 0.9830 - val_loss: 1.1882 - val_accuracy: 0.7675
# Epoch 93/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.0596 - accuracy: 0.9791 - val_loss: 4.7367 - val_accuracy: 0.5800
# Epoch 94/100
# 24/24 [==============================] - 4s 156ms/step - loss: 0.1117 - accuracy: 0.9621 - val_loss: 2.3520 - val_accuracy: 0.6750
# Epoch 95/100
# 24/24 [==============================] - 4s 153ms/step - loss: 0.0467 - accuracy: 0.9869 - val_loss: 1.4813 - val_accuracy: 0.7400
# Epoch 96/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1027 - accuracy: 0.9595 - val_loss: 3.8113 - val_accuracy: 0.6125
# Epoch 97/100
# 24/24 [==============================] - 4s 154ms/step - loss: 0.0500 - accuracy: 0.9778 - val_loss: 1.5479 - val_accuracy: 0.7050
# Epoch 98/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0669 - accuracy: 0.9765 - val_loss: 2.7453 - val_accuracy: 0.6975
# Epoch 99/100
# 24/24 [==============================] - 4s 152ms/step - loss: 0.0659 - accuracy: 0.9856 - val_loss: 1.6366 - val_accuracy: 0.7350
# Epoch 100/100
# 24/24 [==============================] - 4s 155ms/step - loss: 0.1648 - accuracy: 0.9464 - val_loss: 1.2630 - val_accuracy: 0.7275

# %% [markdown]
# And we can plot loss over training iterations...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# Note that we can now reach ~70% accuracy with 100 epochs of learning...

# %%
test_model = keras.models.load_model("Xception.keras")
test_loss, test_acc = test_model.evaluate(test_dataset) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 82s 2s/step - loss: 0.6494 - accuracy: 0.6441
# Test accuracy: 0.6441102623939514
