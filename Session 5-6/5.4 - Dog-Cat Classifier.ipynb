# %% [markdown]
# # Import Our Data

# %% [markdown]
# Load the data to your Google Drive. Then you can mount your drive and access the folder wherever you saved it.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Here, we are using the image_dataset_from_directory utilty, which reads images from a file path into a tf.Dataset object. This is much more memory efficient than reading images into lists! The dataset is already organized into training, test, and validation splits on my file system. The labels are inferred from the folder names.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "drive/My Drive/Teaching/Courses/NYU - Modern AI/Session 5-6/dogs-vs-cats/"

train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 765 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 798 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
     print("data batch shape:", data_batch.shape)
     print("labels batch shape:", labels_batch.shape)
     break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# # Define Our Model

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 178, 178, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 89, 89, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 87, 87, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 43, 43, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 41, 41, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 20, 20, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 18, 18, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 9, 9, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 7, 7, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │          12,545 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We have a binary outcome variable, hence our use of Sigmoid activation on the output layer. We will use binary cross-entropy loss as our loss function. And, we'll monitor accuracy.

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# This callback we are defining will write the current best model (and parameter values) to disk, based on minimum validation loss.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="drive/My Drive/Teaching/Courses/NYU - Modern AI/Session 5-6/convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_accuracy")
]

# %% [markdown]
# Note that batch size isn't defined here, because we defined it when we first created the tf.Dataset object! This Dataset object is an iterator, containing batches of images.

# %%
history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 198s 8s/step - accuracy: 0.5279 - loss: 0.7100 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - accuracy: 0.5324 - loss: 0.6917 - val_accuracy: 0.5000 - val_loss: 0.6914
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.5025 - loss: 0.6955 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 156ms/step - accuracy: 0.5142 - loss: 0.6909 - val_accuracy: 0.5000 - val_loss: 0.6910
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.5430 - loss: 0.6861 - val_accuracy: 0.5025 - val_loss: 0.7017
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.5569 - loss: 0.6678 - val_accuracy: 0.5775 - val_loss: 0.6746
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.6289 - loss: 0.6545 - val_accuracy: 0.6425 - val_loss: 0.6429
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.6554 - loss: 0.6204 - val_accuracy: 0.6475 - val_loss: 0.6452
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.6582 - loss: 0.5986 - val_accuracy: 0.5625 - val_loss: 0.7739
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - accuracy: 0.6735 - loss: 0.5987 - val_accuracy: 0.6625 - val_loss: 0.6203
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7152 - loss: 0.5534 - val_accuracy: 0.7100 - val_loss: 0.6044
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7659 - loss: 0.5019 - val_accuracy: 0.6325 - val_loss: 0.6174
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.7957 - loss: 0.4524 - val_accuracy: 0.7200 - val_loss: 0.5990
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - accuracy: 0.7963 - loss: 0.4488 - val_accuracy: 0.6700 - val_loss: 0.7085
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - accuracy: 0.8092 - loss: 0.4440 - val_accuracy: 0.6650 - val_loss: 0.7883
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8595 - loss: 0.3575 - val_accuracy: 0.6600 - val_loss: 0.6842
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.8864 - loss: 0.3101 - val_accuracy: 0.6750 - val_loss: 0.7546
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - accuracy: 0.8970 - loss: 0.2432 - val_accuracy: 0.6600 - val_loss: 0.8595
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9149 - loss: 0.2236 - val_accuracy: 0.6600 - val_loss: 1.0414
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.9242 - loss: 0.1994 - val_accuracy: 0.6700 - val_loss: 0.9760

# %% [markdown]
# And we can plot loss over training iterations...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# Note that we reach > 65% accuracy pretty quickly without much effort, but it plateaus there.

# %%
test_model = keras.models.load_model("drive/My Drive/Teaching/Courses/NYU - Modern AI/Session 5-6/convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 197s 8s/step - accuracy: 0.6907 - loss: 0.6136
# Test accuracy: 0.7005012631416321

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# To stave off the overfitting, we will first start by augmenting our dataset. This is a simple way to do it in a Sequential model, by adding a data augmentation layer. This step in our model will randomly mess with the data at each pass, flipping, rotating and zooming each image.

# %%
data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

# %% [markdown]
# You'll see that adding the aaumentation layer gets us another 5% bump in the validation accuracy of our model, up to about 72% fairly consistently. Note that we do a bit worse than the textbook claims, because we are using less data (I kept about 40% of the sample the book was working with).

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# We are making a different callback so we don't overwrite our last model (we might want to compare them)
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]

# And let's fit the model.
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 240ms/step - accuracy: 0.4683 - loss: 0.7396 - val_accuracy: 0.5000 - val_loss: 0.6922
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.5144 - loss: 0.7143 - val_accuracy: 0.5000 - val_loss: 0.6909
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.5282 - loss: 0.6904 - val_accuracy: 0.6025 - val_loss: 0.6900
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.5373 - loss: 0.6948 - val_accuracy: 0.6250 - val_loss: 0.6822
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - accuracy: 0.5836 - loss: 0.7138 - val_accuracy: 0.5125 - val_loss: 0.6818
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.5753 - loss: 0.6721 - val_accuracy: 0.6550 - val_loss: 0.6455
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6035 - loss: 0.6749 - val_accuracy: 0.5950 - val_loss: 0.6834
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - accuracy: 0.6116 - loss: 0.6683 - val_accuracy: 0.6475 - val_loss: 0.6282
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6607 - loss: 0.6429 - val_accuracy: 0.5525 - val_loss: 0.9000
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.6313 - loss: 0.6352 - val_accuracy: 0.6800 - val_loss: 0.6006
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - accuracy: 0.6940 - loss: 0.5919 - val_accuracy: 0.6225 - val_loss: 0.6657
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.6846 - loss: 0.5951 - val_accuracy: 0.6475 - val_loss: 0.6046
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.6642 - loss: 0.6036 - val_accuracy: 0.6875 - val_loss: 0.6024
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.6821 - loss: 0.6194 - val_accuracy: 0.7125 - val_loss: 0.5919
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.7133 - loss: 0.5509 - val_accuracy: 0.6975 - val_loss: 0.5850
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7044 - loss: 0.5731 - val_accuracy: 0.7050 - val_loss: 0.5556
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6944 - loss: 0.5962 - val_accuracy: 0.6925 - val_loss: 0.6164
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.7187 - loss: 0.5420 - val_accuracy: 0.7350 - val_loss: 0.5606
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6895 - loss: 0.5688 - val_accuracy: 0.7200 - val_loss: 0.5440
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.7484 - loss: 0.5147 - val_accuracy: 0.7075 - val_loss: 0.5476
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - accuracy: 0.7503 - loss: 0.5205 - val_accuracy: 0.6875 - val_loss: 0.6138
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.7202 - loss: 0.5747 - val_accuracy: 0.7025 - val_loss: 0.6370
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━
100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9589 - loss: 0.1072 - val_accuracy: 0.7550 - val_loss: 1.0795
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.9523 - loss: 0.1284 - val_accuracy: 0.7675 - val_loss: 1.0850
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9640 - loss: 0.1047 - val_accuracy: 0.7550 - val_loss: 1.0960
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 204ms/step - accuracy: 0.9656 - loss: 0.0953 - val_accuracy: 0.7375 - val_loss: 0.9937
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9602 - loss: 0.1468 - val_accuracy: 0.7700 - val_loss: 0.9739
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 214ms/step - accuracy: 0.9757 - loss: 0.0611 - val_accuracy: 0.7925 - val_loss: 1.0712
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.9652 - loss: 0.1166 - val_accuracy: 0.7800 - val_loss: 0.9898

# %% [markdown]
# Let's plot the accuracy over training again...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And let's check the test accuracy.

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7379 - loss: 1.3454
# Test accuracy: 0.7481203079223633

# %% [markdown]
# # Feature Extraction from a Pre-Trained Model: VGG16

# %% [markdown]
# Now we are going to load a pre-trained model, to leverage its convolutional base for our task. Note that the convolutional base, alone, is about 15 million parameters.

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False, # Throw away the densely connected layer at the end.
    input_shape=(180, 180, 3)) # Optional - just for model.summary() call.

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 180, 180, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 180, 180, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 90, 90, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 90, 90, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 90, 90, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 45, 45, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 45, 45, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 45, 45, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 45, 45, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 22, 22, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 22, 22, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 22, 22, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 22, 22, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 11, 11, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 11, 11, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 11, 11, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 11, 11, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 5, 5, 512)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Now we run our training, validation, and test data images through the convolutional base, get the feature representations of each according to VGG, and then store them alongside their cat/dog labels.

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %% [markdown]
# Here, you can see the dimensionality of the features associated with a single image. The VGG output from the convolutional layer comprises of 512 feature-specific feature maps, that are each 5x5 in dimensionality.

# %%
print(train_features[0].shape)
# Out:
# (5, 5, 512)

# %% [markdown]
# So, now we are going to define a new model that sits on the end of the VGG convolutional layer. It'll take those 512 featuremaps, flatten them, pass them to a Dense layer of 256 nodes, and then feed to a one-node sigmoid output (with some Dropout). This model will fit extremely quickly, and it's accuracy will be way higher, approaching 97%

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_accuracy")
]

history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.7698 - loss: 46.7112 - val_accuracy: 0.9625 - val_loss: 3.4623
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9924 - loss: 1.2276 - val_accuracy: 0.9475 - val_loss: 6.5465
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9866 - loss: 0.8901 - val_accuracy: 0.9450 - val_loss: 9.3351
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - loss: 0.5238 - val_accuracy: 0.8975 - val_loss: 15.7864
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9885 - loss: 1.0974 - val_accuracy: 0.9500 - val_loss: 7.0029
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9952 - loss: 0.3835 - val_accuracy: 0.9300 - val_loss: 8.2513
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.4948 - val_accuracy: 0.9400 - val_loss: 13.6278
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.3614 - val_accuracy: 0.9475 - val_loss: 14.0857
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.0786 - val_accuracy: 0.9450 - val_loss: 14.0514
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.8903e-18 - val_accuracy: 0.9450 - val_loss: 14.0514
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.3442 - val_accuracy: 0.9475 - val_loss: 6.7456
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9892 - loss: 1.4292 - val_accuracy: 0.9475 - val_loss: 8.8713
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.1826e-04 - val_accuracy: 0.9500 - val_loss: 14.2590
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0027 - val_accuracy: 0.9475 - val_loss: 7.1598
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.4308e-26 - val_accuracy: 0.9475 - val_loss: 7.1598
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.5084e-14 - val_accuracy: 0.9475 - val_loss: 7.1598
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.6640e-14 - val_accuracy: 0.9475 - val_loss: 7.1598
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9995 - loss: 3.6351e-04 - val_accuracy: 0.9400 - val_loss: 18.2199
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9982 - loss: 0.3620 - val_accuracy: 0.9450 - val_loss: 16.7542
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9965 - loss: 0.3358 - val_accuracy: 0.9500 - val_loss: 7.9970

# %% [markdown]
# Plotting performance here...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And, evaluating performance on the test data.

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features,test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9697 - loss: 3.2244
# Test accuracy: 0.9624060392379761

# %% [markdown]
# # Fine-Tuning from a Pre-Trained Model (with Data-Augmentation)

# %% [markdown]
# Here we are going to load the convolutional base, and actually use it inside our network (though we will freeze its parameters so we don't try to update them as we go, since that would ruin the model and add lots of computation time).

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)

conv_base.trainable = False # The convolutional layers won't be updatable; we just build on them using Functional API.

data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6             │ (None, 180, 180, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential_1 (Sequential) │ (None, 180, 180, 3)    │              0 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item (GetItem)        │ (None, 180, 180)       │              0 │ sequential_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_1 (GetItem)      │ (None, 180, 180)       │              0 │ sequential_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_2 (GetItem)      │ (None, 180, 180)       │              0 │ sequential_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack (Stack)             │ (None, 180, 180, 3)    │              0 │ get_item[0][0],        │
# │                           │                        │                │ get_item_1[0][0],      │
# │                           │                        │                │ get_item_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 180, 180, 3)    │              0 │ stack[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ vgg16 (Functional)        │ (None, 5, 5, 512)      │     14,714,688 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_3 (Flatten)       │ (None, 12800)          │              0 │ vgg16[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 256)            │      3,277,056 │ flatten_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 256)            │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1)              │            257 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 17,992,001 (68.63 MB)
#  Trainable params: 3,277,313 (12.50 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# And now we can fit our model. This is slower because our forward pass has to go through the VGG convolutional base each iteration (rather than the one time we did when we used it for feature extraction.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(
    train_dataset, # Note we are back to working with our original training dataset.
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 13s 317ms/step - accuracy: 0.7323 - loss: 68.2698 - val_accuracy: 0.9475 - val_loss: 6.4377
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 217ms/step - accuracy: 0.9646 - loss: 4.6308 - val_accuracy: 0.9400 - val_loss: 5.5466
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 233ms/step - accuracy: 0.9597 - loss: 4.5763 - val_accuracy: 0.9400 - val_loss: 8.5893
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━