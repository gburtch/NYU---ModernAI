# %% [markdown]
# #**Extreme Overfitting Example**

# %% [markdown]
# I'm going to simulate a set of random images and their associated labels. I want to then fit a neural network to the random data. Finally, report how accurate the model is on the training data, and visualize training accuracy across epochs.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from PIL import Image as im

# Let's synthesize 20,000 images comprised of random pixel values.
train_images_random = np.random.random((5000, 28,28))
df = pd.DataFrame(train_images_random.reshape(-1)) #-1 will drop the last dimension from the tensor and collapse it into the one prior.
print(f'Descriptive statistics for the training data:\n{df.describe()}\n')

# And let's make-up labels for them.
train_labels_random = np.floor(np.random.random(5000)*10)
print(f'The first ten labels are {train_labels_random[:10]}\n')

# Here's what the first picture looks like.
plt.imshow(train_images_random[0],cmap=plt.cm.binary)
plt.show()

# Let's first convert each pixel matrix into a vector.
train_images_random = train_images_random.reshape(5000,28*28)
train_labels_random = train_labels_random.reshape(5000,1)
print(train_images_random.shape)
print(train_labels_random.shape)
# Out:
# Descriptive statistics for the training data:
#                   0
# count  3.920000e+06
# mean   4.998794e-01
# std    2.886732e-01
# min    1.229973e-07
# 25%    2.498437e-01
# 50%    4.998473e-01
# 75%    7.498650e-01
# max    9.999994e-01
#
# The first ten labels are [0. 1. 7. 3. 5. 1. 7. 6. 4. 3.]
# (5000, 784)
# (5000, 1)

# %% [markdown]
# Now we will use the simulated data and fit a sequential Keras model that has 512 units in the first layer, with a Relu activation, and then the output layer.

# %%
# Setup your model topology here using the Sequential API, as before.
model = keras.Sequential([
      layers.Dense(512,activation="relu"),
      layers.Dense(10, activation="softmax")
])

# Compile your model
model.compile(optimizer="sgd",loss="sparse_categorical_crossentropy",metrics=['accuracy'])

# Fit your model and store the training history in a variable (history) that you can query to plot the training loss, later.
history = model.fit(train_images_random,train_labels_random, batch_size=25,epochs=30)
# Out:
# Epoch 1/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.1086 - loss: 2.3599
# Epoch 2/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1275 - loss: 2.3121
# Epoch 3/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1419 - loss: 2.2793
# Epoch 4/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1568 - loss: 2.2609
# Epoch 5/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1729 - loss: 2.2345
# Epoch 6/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1928 - loss: 2.2209
# Epoch 7/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2047 - loss: 2.1995
# Epoch 8/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2234 - loss: 2.1800
# Epoch 9/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2426 - loss: 2.1450
# Epoch 10/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2575 - loss: 2.1284
# Epoch 11/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2664 - loss: 2.1065
# Epoch 12/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3092 - loss: 2.0722
# Epoch 13/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3093 - loss: 2.0514
# Epoch 14/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3132 - loss: 2.0314
# Epoch 15/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3353 - loss: 2.0093
# Epoch 16/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3470 - loss: 1.9809
# Epoch 17/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3679 - loss: 1.9501
# Epoch 18/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3723 - loss: 1.9186
# Epoch 19/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3855 - loss: 1.9101
# Epoch 20/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3985 - loss: 1.8745
# Epoch 21/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4023 - loss: 1.8547
# Epoch 22/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4284 - loss: 1.8163
# Epoch 23/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4317 - loss: 1.7966
# Epoch 24/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4255 - loss: 1.7743
# Epoch 25/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4533 - loss: 1.7301
# Epoch 26/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4551 - loss: 1.7136
# Epoch 27/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4811 - loss: 1.6782
# Epoch 28/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4871 - loss: 1.6431
# Epoch 29/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4817 - loss: 1.6234
# Epoch 30/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4986 - loss: 1.6122

# %% [markdown]
# Okay, plot the training loss now...

# %%
# Call plot commands here.
plt.plot(history.history['loss'])
plt.show()
